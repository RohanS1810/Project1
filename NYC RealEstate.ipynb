# %%
#1 Calculate the highest sales price in each of the 5 city in a year Manhattan Manhattan Bronx Brooklyn Queens Staten island
#2 Calculate the lowest sales price in each of the 5 city in a year Manhattan Bronx Brooklyn Queens Staten island
#3 Group the data by neighborhood and average sales price for each neighborhood in NYC City
#4 Created a bar chart for #3
#5 Calculate which Building Class category was sold the most for all the 5 Borough
#6 Bar chart - for all 5 bourough and each bar sliced by Building Class category
#7 Geo-plot the neighborhood housing units sold for each city in a year 2022-2023 Manhattan Bronx Brooklyn Queens Staten island
#8 Link: https://tome.app/seemaa/new-york-real-estate-fintech-cleex07bi00d86o40rb0v1b39

# %%
# Import the required libraries
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import hvplot.pandas
import geoviews as gv
from geoviews import dim, opts

# %%
Manhattan_df = pd.read_csv(Path("rollingsales_manhattan.csv"))
Manhattan_df.head()
# Out:
#    BOROUGH   NEIGHBORHOOD         BUILDING CLASS CATEGORY  \
# 0        1  ALPHABET CITY         01 ONE FAMILY DWELLINGS
# 1        1  ALPHABET CITY         02 TWO FAMILY DWELLINGS
# 2        1  ALPHABET CITY         02 TWO FAMILY DWELLINGS
# 3        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
#
#   TAX CLASS AT PRESENT  BLOCK  LOT  EASEMENT BUILDING CLASS AT PRESENT  \
# 0                    1    374   46       NaN                        A4
# 1                    1    372   36       NaN                        S2
# 2                    1    377    1       NaN                        S2
# 3                   2B    373   16       NaN                        C1
# 4                   2B    373   17       NaN                        C1
#
#                ADDRESS APARTMENT NUMBER  ...  RESIDENTIAL UNITS  \
# 0  347 EAST 4TH STREET              NaN  ...                  1
# 1          19 AVENUE D              NaN  ...                  2
# 2         110 AVENUE C              NaN  ...                  2
# 3  326 EAST 4TH STREET              NaN  ...                 10
# 4  328 EAST 4TH STREET              NaN  ...                 10
#
#   COMMERCIAL UNITS  TOTAL UNITS LAND SQUARE FEET GROSS SQUARE FEET YEAR BUILT  \
# 0              0.0            1            2,116             4,400     1900.0
# 1              1.0            3              825             2,481     1900.0
# 2              1.0            3            1,502             2,790     1901.0
# 3              0.0           10            2,204             8,625     1899.0
# 4              0.0           10            2,204             8,625     1900.0
#
#    TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  SALE PRICE   \
# 0                          1                              A4      399,000
# 1                          1                              S2            1
# 2                          1                              S2    2,999,999
# 3                          2                              C1   16,800,000
# 4                          2                              C1   16,800,000
#
#    SALE DATE
# 0  9/29/2022
# 1  1/20/2023
# 2  9/15/2022
# 3   8/4/2022
# 4   8/4/2022
#
# [5 rows x 21 columns]

# %%
Brooklyndata_df = pd.read_csv(Path("rollingsales_brooklyn.csv"))
Queensdata_df = pd.read_csv(Path("rollingsales_queens.csv"))
statendata_df = pd.read_csv(Path("rollingsales_statenisland.csv"))

# %%
Bronxdata_df = pd.read_csv(Path("rollingsales_bronx.csv"))

# %%
#Concat function to add all the NYC neighborhood data
all_neighborhoods_df = pd.concat(
    [Brooklyndata_df, Manhattan_df, Queensdata_df, statendata_df, Bronxdata_df], 
    axis="rows",
    sort=False,
)
all_neighborhoods_df.head()
# Out:
#    BOROUGH NEIGHBORHOOD  BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0        3   BATH BEACH  01 ONE FAMILY DWELLINGS                    1   6360
# 1        3   BATH BEACH  01 ONE FAMILY DWELLINGS                    1   6360
# 2        3   BATH BEACH  01 ONE FAMILY DWELLINGS                    1   6363
# 3        3   BATH BEACH  01 ONE FAMILY DWELLINGS                    1   6363
# 4        3   BATH BEACH  01 ONE FAMILY DWELLINGS                    1   6372
#
#    LOT  EASEMENT BUILDING CLASS AT PRESENT             ADDRESS  \
# 0   56       NaN                        A5           30 BAY 10
# 1  157       NaN                        A5  36 BAY 10TH STREET
# 2   48       NaN                        A9      12 BAY 13TH ST
# 3   62       NaN                        A9  44 BAY 13TH STREET
# 4   34       NaN                        A9    8637 19TH AVENUE
#
#   APARTMENT NUMBER  ...  RESIDENTIAL UNITS COMMERCIAL UNITS TOTAL UNITS  \
# 0              NaN  ...                1.0              0.0         1.0
# 1              NaN  ...                1.0              0.0         1.0
# 2              NaN  ...                1.0              0.0         1.0
# 3              NaN  ...                1.0              0.0         1.0
# 4              NaN  ...                1.0              0.0         1.0
#
#   LAND SQUARE FEET GROSS SQUARE FEET YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 0            1,546             1,428     1930.0                          1
# 1            1,547             1,428     1930.0                          1
# 2            3,142             3,200     1999.0                          1
# 3            3,575             2,104     1901.0                          1
# 4            2,417             2,154     1930.0                          1
#
#    BUILDING CLASS AT TIME OF SALE  SALE PRICE    SALE DATE
# 0                              A5       75,000    6/1/2022
# 1                              A5            0   3/18/2022
# 2                              A9            0   3/14/2022
# 3                              A9      990,000  10/18/2022
# 4                              A9            0   9/20/2022
#
# [5 rows x 21 columns]

# %%
all_neighborhoods_df.columns
#converting SALE PRICE to Numeric 
all_neighborhoods_df[' SALE PRICE '] = all_neighborhoods_df[' SALE PRICE '].str.replace(',','')
all_neighborhoods_df[' SALE PRICE '] = all_neighborhoods_df[' SALE PRICE '].apply(pd.to_numeric)
all_neighborhoods_df
# Out:
#       BOROUGH NEIGHBORHOOD         BUILDING CLASS CATEGORY  \
# 0           3   BATH BEACH         01 ONE FAMILY DWELLINGS
# 1           3   BATH BEACH         01 ONE FAMILY DWELLINGS
# 2           3   BATH BEACH         01 ONE FAMILY DWELLINGS
# 3           3   BATH BEACH         01 ONE FAMILY DWELLINGS
# 4           3   BATH BEACH         01 ONE FAMILY DWELLINGS
# ...       ...          ...                             ...
# 6969        2     WOODLAWN  10 COOPS - ELEVATOR APARTMENTS
# 6970        2     WOODLAWN  10 COOPS - ELEVATOR APARTMENTS
# 6971        2     WOODLAWN  10 COOPS - ELEVATOR APARTMENTS
# 6972        2     WOODLAWN              22 STORE BUILDINGS
# 6973        2     WOODLAWN              22 STORE BUILDINGS
#
#      TAX CLASS AT PRESENT  BLOCK  LOT  EASEMENT BUILDING CLASS AT PRESENT  \
# 0                       1   6360   56       NaN                        A5
# 1                       1   6360  157       NaN                        A5
# 2                       1   6363   48       NaN                        A9
# 3                       1   6363   62       NaN                        A9
# 4                       1   6372   34       NaN                        A9
# ...                   ...    ...  ...       ...                       ...
# 6969                    2   3398   97       NaN                        D4
# 6970                    2   3398   97       NaN                        D4
# 6971                    2   3398   97       NaN                        D4
# 6972                    4   3380   46       NaN                        K1
# 6973                    4   3385    5       NaN                        K4
#
#                       ADDRESS APARTMENT NUMBER  ...  RESIDENTIAL UNITS  \
# 0                   30 BAY 10              NaN  ...                1.0
# 1          36 BAY 10TH STREET              NaN  ...                1.0
# 2              12 BAY 13TH ST              NaN  ...                1.0
# 3          44 BAY 13TH STREET              NaN  ...                1.0
# 4            8637 19TH AVENUE              NaN  ...                1.0
# ...                       ...              ...  ...                ...
# 6969  4295 WEBSTER AVENUE, 5C              NaN  ...                NaN
# 6970  4295 WEBSTER AVENUE, 6K              NaN  ...                NaN
# 6971  4295 WEBSTER AVENUE, L4              NaN  ...                NaN
# 6972      4361 KATONAH AVENUE              NaN  ...                0.0
# 6973      4300 KATONAH AVENUE              NaN  ...                2.0
#
#      COMMERCIAL UNITS TOTAL UNITS LAND SQUARE FEET GROSS SQUARE FEET  \
# 0                 0.0         1.0            1,546             1,428
# 1                 0.0         1.0            1,547             1,428
# 2                 0.0         1.0            3,142             3,200
# 3                 0.0         1.0            3,575             2,104
# 4                 0.0         1.0            2,417             2,154
# ...               ...         ...              ...               ...
# 6969              NaN         NaN              NaN               NaN
# 6970              NaN         NaN              NaN               NaN
# 6971              NaN         NaN              NaN               NaN
# 6972              1.0         1.0            9,698             3,400
# 6973              2.0         4.0            2,330             2,425
#
#      YEAR BUILT  TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  \
# 0        1930.0                          1                              A5
# 1        1930.0                          1                              A5
# 2        1999.0                          1                              A9
# 3        1901.0                          1                              A9
# 4        1930.0                          1                              A9
# ...         ...                        ...                             ...
# 6969     1957.0                          2                              D4
# 6970     1957.0                          2                              D4
# 6971     1957.0                          2                              D4
# 6972     1970.0                          4                              K1
# 6973     1931.0                          4                              K4
#
#       SALE PRICE    SALE DATE
# 0           75000    6/1/2022
# 1               0   3/18/2022
# 2               0   3/14/2022
# 3          990000  10/18/2022
# 4               0   9/20/2022
# ...           ...         ...
# 6969       904225   6/30/2022
# 6970       904225   6/30/2022
# 6971       904225   6/30/2022
# 6972            0  12/12/2022
# 6973            0   5/17/2022
#
# [89009 rows x 21 columns]

# %%
#Calculate the highest sales price in each of the 5 city in a year Manhattan Manhattan Bronx Brooklyn Queens Staten island
max_prices = all_neighborhoods_df.groupby('NEIGHBORHOOD')[' SALE PRICE '].max()
max_prices
# Out:
# NEIGHBORHOOD
# AIRPORT LA GUARDIA      900000
# ALPHABET CITY         64000000
# ANNADALE               2585000
# ARDEN HEIGHTS          1303360
# ARROCHAR               1100000
#                         ...
# WOODHAVEN              7745625
# WOODLAWN               8000000
# WOODROW                5600000
# WOODSIDE              17400000
# WYCKOFF HEIGHTS        6500000
# Name:  SALE PRICE , Length: 252, dtype: int64

# %%
#Calculate the highest sales price in each of the Neighborhood for the 5 Borough's
max_prices.hvplot.bar(
    x='NEIGHBORHOOD',
    y=' SALE PRICE ',
    xlabel='Neighborhood',
    ylabel='Max Sale Price',
    title='Max Sale Prices by Neighborhood',
    height=1000,
    width=1200
).opts(yformatter='%.0f')
# Out:
# :Bars   [NEIGHBORHOOD]   ( SALE PRICE )

# %% [markdown]
# Max house prices is 931 million in upper east side

# %%
#Hvplot of highest sales price in each of the Neighborhood for the 5 Borough's
max_prices.hvplot.bar(
    x="NEIGHBORHOOD",
    xlabel="NEIGHBORHOOD",
    ylabel="SALE PRICE",
    groupby="NEIGHBORHOOD",
    title="Sale Price By Neighborhood"
).opts(yformatter='%.0f')
# Out:
# :DynamicMap   [NEIGHBORHOOD]
#    :Bars   [NEIGHBORHOOD,Variable]   (value)

# %%
df_filtered = all_neighborhoods_df.loc[all_neighborhoods_df[' SALE PRICE '] > 5000]

# %%
#2 Calculate the min sales price in each of the 5 city in a year Manhattan Bronx Brooklyn Queens Staten island
min_prices = df_filtered.groupby('NEIGHBORHOOD')[' SALE PRICE '].min()
min_prices
# Out:
# NEIGHBORHOOD
# AIRPORT LA GUARDIA    335000
# ALPHABET CITY          21919
# ANNADALE               31600
# ARDEN HEIGHTS          40000
# ARROCHAR              530000
#                        ...
# WOODHAVEN             165500
# WOODLAWN               95000
# WOODROW                40000
# WOODSIDE               28000
# WYCKOFF HEIGHTS        40000
# Name:  SALE PRICE , Length: 251, dtype: int64

# %%
#3 Group the data by neighborhood and average sales price for each neighborhood in NYC City
mean_prices = all_neighborhoods_df.groupby('NEIGHBORHOOD')[' SALE PRICE '].mean()
mean_prices
# Out:
# NEIGHBORHOOD
# AIRPORT LA GUARDIA    5.467744e+05
# ALPHABET CITY         1.990911e+06
# ANNADALE              6.254232e+05
# ARDEN HEIGHTS         3.989938e+05
# ARROCHAR              5.048604e+05
#                           ...
# WOODHAVEN             5.246306e+05
# WOODLAWN              5.281985e+05
# WOODROW               6.124474e+05
# WOODSIDE              7.262270e+05
# WYCKOFF HEIGHTS       8.814696e+05
# Name:  SALE PRICE , Length: 252, dtype: float64

# %%
# group the data by borough and average sales price for each neighbourhood in NYC City
mean_prices.hvplot.bar(
    x='NEIGHBORHOOD',
    y=' SALE PRICE ',
    xlabel='Neighborhood',
    ylabel='Average Sale Price',
    title='Average Sale Prices by Neighborhood',
    height=1000,
    width=1200
).opts(yformatter='%.0f')
# Out:
# :Bars   [NEIGHBORHOOD]   ( SALE PRICE )

# %%
#Calculate which Building Class category was sold the most in the 5 nyc boroughs and build a bar plot for  building classes categrory for each borough

# %%
building_class_counts = all_neighborhoods_df.groupby('BOROUGH')['BUILDING CLASS CATEGORY'].count()
building_class_counts
# Out:
# BOROUGH
# 1    20896
# 2     6974
# 3    25554
# 4    27601
# 5     7984
# Name: BUILDING CLASS CATEGORY, dtype: int64

# %%
# sort the counts in descending order and select the top 10 categories
top_building_classes = building_class_counts.sort_values(ascending=False).head(10)
top_building_classes
# Out:
# BOROUGH
# 4    27601
# 3    25554
# 1    20896
# 5     7984
# 2     6974
# Name: BUILDING CLASS CATEGORY, dtype: int64

# %%
# reset the index to turn the Series into a DataFrame
top_building_classes = top_building_classes.reset_index()
top_building_classes
# Out:
#    BOROUGH  BUILDING CLASS CATEGORY
# 0        4                    27601
# 1        3                    25554
# 2        1                    20896
# 3        5                     7984
# 4        2                     6974

# %%
listbuildingclass_df = all_neighborhoods_df.groupby(['BOROUGH','BUILDING CLASS CATEGORY']).size()
listbuildingclass_df
buildingclasscategory_df = listbuildingclass_df.to_frame(name = 'size').reset_index()
buildingclasscategory_df
# Out:
#      BOROUGH         BUILDING CLASS CATEGORY  size
# 0          1         01 ONE FAMILY DWELLINGS   170
# 1          1         02 TWO FAMILY DWELLINGS   121
# 2          1       03 THREE FAMILY DWELLINGS    79
# 3          1           04 TAX CLASS 1 CONDOS    16
# 4          1  07 RENTALS - WALKUP APARTMENTS   644
# ..       ...                             ...   ...
# 185        5            38 ASYLUMS AND HOMES     2
# 186        5          41 TAX CLASS 4 - OTHER     8
# 187        5       43 CONDO OFFICE BUILDINGS     2
# 188        5                44 CONDO PARKING    11
# 189        5        46 CONDO STORE BUILDINGS     2
#
# [190 rows x 3 columns]

# %%
#Manhattan = 1, Bronox = 2, Brooklyn = 3, Queens = 4 , Staten island = 5
layout = buildingclasscategory_df.hvplot.bar(
    x='BOROUGH', 
    y='size', 
    by='BUILDING CLASS CATEGORY', 
    #groupby='BUILDING CLASS CATEGORY', 
    stacked=True, 
    cmap='Category20', 
    #legend='top_left',
    width=1500,
    xlabel='',
)
layout
# Out:
# :Bars   [BOROUGH,BUILDING CLASS CATEGORY]   (size)

# %%
#US city population
uscitiesdf = pd.read_csv(Path("uscities.csv"))
uscitiesdf.head()
# Out:
#           city   city_ascii state_id  state_name  county_fips  county_name  \
# 0     New York     New York       NY    New York        36081       Queens
# 1  Los Angeles  Los Angeles       CA  California         6037  Los Angeles
# 2      Chicago      Chicago       IL    Illinois        17031         Cook
# 3        Miami        Miami       FL     Florida        12086   Miami-Dade
# 4       Dallas       Dallas       TX       Texas        48113       Dallas
#
#        lat       lng  population  density source  military  incorporated  \
# 0  40.6943  -73.9249    18972871  10768.2  shape     False          True
# 1  34.1141 -118.4068    12121244   3267.6  shape     False          True
# 2  41.8375  -87.6866     8595181   4576.6  shape     False          True
# 3  25.7840  -80.2101     5711945   4945.7  shape     False          True
# 4  32.7935  -96.7667     5668165   1522.2  shape     False          True
#
#               timezone  ranking  \
# 0     America/New_York        1
# 1  America/Los_Angeles        1
# 2      America/Chicago        1
# 3     America/New_York        1
# 4      America/Chicago        1
#
#                                                 zips          id
# 0  11229 11226 11225 11224 11223 11221 11220 1138...  1840034016
# 1  90291 90293 90292 91316 91311 90035 90034 9003...  1840020491
# 2  60018 60649 60641 60640 60643 60642 60645 6064...  1840000494
# 3  33128 33129 33125 33126 33127 33149 33144 3314...  1840015149
# 4  75287 75098 75234 75254 75251 75252 75253 7503...  1840019440

# %%
uscitiesdf.columns
# Out:
# Index(['city', 'city_ascii', 'state_id', 'state_name', 'county_fips',
#        'county_name', 'lat', 'lng', 'population', 'density', 'source',
#        'military', 'incorporated', 'timezone', 'ranking', 'zips', 'id'],
#       dtype='object')

# %%
uscitiesdf['population'] = uscitiesdf['population'].astype('int')
#uscitiesdf['population'] = uscitiesdf['population']

# %%
uscitiesdf['lat'] = uscitiesdf['lat'].astype('float')

# %%
uscitiesdf['lng'] = uscitiesdf['lng'].astype('float')

# %%
uscitiesdf.hvplot.points(
    'lng', 
    'lat', 
    geo=True, 
    color='state_name',
    #size='population',
    #by='state_name',
    #hovercalls
    tiles='OSM',
    frame_width=700,
    frame_height=500,
    title="Population in US cities")
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [lng,lat]   (state_name)

# %%
nyc_df = uscitiesdf.loc[uscitiesdf['state_name']=='New York']
nyc_df
# Out:
#                 city     city_ascii state_id state_name  county_fips  \
# 0           New York       New York       NY   New York        36081
# 16          Brooklyn       Brooklyn       NY   New York        36047
# 19            Queens         Queens       NY   New York        36081
# 32         Manhattan      Manhattan       NY   New York        36061
# 40             Bronx          Bronx       NY   New York        36005
# ...              ...            ...      ...        ...          ...
# 29768       Saltaire       Saltaire       NY   New York        36103
# 29896      Witherbee      Witherbee       NY   New York        36031
# 30121        Linwood        Linwood       NY   New York        36051
# 30423  Dering Harbor  Dering Harbor       NY   New York        36103
# 30738     Watchtower     Watchtower       NY   New York        36111
#
#       county_name      lat      lng  population  density source  military  \
# 0          Queens  40.6943 -73.9249    18972871  10768.2  shape     False
# 16          Kings  40.6501 -73.9496     2736074  15200.5  point     False
# 19         Queens  40.7498 -73.7976     2405464   8503.7  point     False
# 32       New York  40.7834 -73.9662     1694263  28653.9  point     False
# 40          Bronx  40.8501 -73.8662     1472654  13356.3  point     False
# ...           ...      ...      ...         ...      ...    ...       ...
# 29768     Suffolk  40.6389 -73.1949          27     70.2  shape     False
# 29896       Essex  44.0824 -73.5339          23     81.6  shape     False
# 30121  Livingston  42.8967 -77.9476          14     24.9  shape     False
# 30423     Suffolk  41.0933 -72.3418           0     34.1  shape     False
# 30738      Ulster  41.6370 -74.2633           0   1136.4  shape     False
#
#        incorporated          timezone  ranking  \
# 0              True  America/New_York        1
# 16             True  America/New_York        1
# 19             True  America/New_York        1
# 32             True  America/New_York        1
# 40             True  America/New_York        1
# ...             ...               ...      ...
# 29768          True  America/New_York        3
# 29896         False  America/New_York        3
# 30121         False  America/New_York        3
# 30423          True  America/New_York        3
# 30738         False  America/New_York        3
#
#                                                     zips          id
# 0      11229 11226 11225 11224 11223 11221 11220 1138...  1840034016
# 16     11229 11226 11225 11224 11223 11221 11220 1124...  1840034030
# 19     11385 11109 11102 11103 11106 11104 11379 1137...  1840034002
# 32     10169 10168 10167 10165 10162 10282 10280 1004...  1840034000
# 40     10452 10475 10474 10471 10470 10473 10472 1045...  1840033999
# ...                                                  ...         ...
# 29768                                              11706  1840005135
# 29896                                              12998  1840023958
# 30121                                              14486  1840024077
# 30423                                              11964  1840005146
# 30738                                              12589  1840026219
#
# [971 rows x 17 columns]

# %%
nyc_df.hvplot.points(
    'lng', 
    'lat', 
    geo=True, 
    color='city',
    size='density',
    tiles='OSM',
    frame_width=700,
    frame_height=500,
    title="Population in NYC cities")
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [lng,lat]   (city,density)
